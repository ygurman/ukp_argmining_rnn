# %%
import numpy as np
import torch

# %%
import re

def getNewLineIndices(text:str) -> np.array:
    i = 0 # assume first char always opens paragraph
    paragraph_indices = []
    while i != -1:
        paragraph_indices.append(i)
        i = text.find('\n', i + 1)
    
    return np.array(paragraph_indices)

# %%
# parse data from ".ann" UKP 2.0 files
def readAnnotatedFile(ann_path:str) -> (dict, dict, dict, list, list):
    propositions, prop_labels, prop_stances, supports, attacks = {}, {}, {}, [], []
    with open(file=ann_path, mode='rt', encoding='utf8') as f:
        for line in f:
            delimited = line.split('\t')
            typ = delimited[0][0] # T == proposition , A = Stance, R = link
            inner_index = int(delimited[0][1:])
            data = delimited[1].split()
            
            if typ == 'T':
                label = data[0] # prop lable (Premise, Cliam or MajorClaim)
                start, end = int(data[1]), int(data[2]) # proposition offsets
                propositions[inner_index] = (start, end) # represent propositions by it's index boundries
                prop_labels[inner_index] = label
                
            elif typ == 'A':
                _, target_index, stance_value = data # first Column in "A" lines is always "Stance", stance value in {For, Against}
                prop_stances[int(target_index[1:])] = stance_value
                
            elif typ == 'R':
                link_typ = data[0] # link type in {supports, attacks}
                source, target = int(data[1][6:]), int(data[2][6:]) #get inner indices of related propositions (ex:Arg1:T4 Arg2:T3 -> source == 4 , target = 3)
                link_list = supports if link_typ == 'supports' else attacks
                link_list.append((source,target))
    
    return propositions, prop_labels, prop_stances, supports, attacks

# %%
class ArgDoc(object):
    def __init__(self, base_path):
        self.ess_id = int(base_path[-3:]) # essay id according to UKP naming convention
        self._txt_path = base_path + ".txt" # essay text file path
        self._ann_path = base_path + ".ann" # UKP annotated file path
        # read document's text
        with open(file=self._txt_path, mode='rt', encoding='utf8') as f:
            self.text = f.read()
        
        # get essay's paragraph's indices (seperated with '\n')
        self.paragraph_offsets = getNewLineIndices(self.text)
        
        # read annotated data from file
        propositions, prop_labels, prop_stances, supports, attacks = readAnnotatedFile(self._ann_path)
        
        # update proposition offsets, labels, stances and link types
        inner_indices, self.prop_offsets = zip(*sorted(propositions.items(), key = lambda x: x[1])) # use the beginning index of propositions for sort
       
        # paragraph alignmnt of propositions (ordered by proposition's offsets)
        self.prop_paragraphs = [np.searchsorted(self.paragraph_offsets, start) -1 for start, _ in self.prop_offsets]
        
        # invert indices for key management 
        new_indices = {k: v for v, k in enumerate(inner_indices)}
        n_props = len(self.prop_offsets)
        
        # update fields with new inverted indices
        self.prop_labels = [prop_labels[inner_indices[i]] for i in range(n_props)]
        self.prop_stances = {new_indices[k]: v for k,v in prop_stances.items()}
        self.supports = [(new_indices[src], new_indices[trg]) for src, trg in supports]
        self.attacks = [(new_indices[src], new_indices[trg]) for src, trg in attacks]
        self.links = self.supports + self.attacks

# %%
class ArgMLModel(object):
    def __init__():
        # TODO
        pass

# %%
import os
def visualizeUKPArgDoc(doc:ArgDoc, output_path):
    """
    visualise UKP argument essay object and save to png
    """
    import pydot
    arg_graph = pydot.Dot(graph_type='digraph')
    
    maj_claims = [("! " + doc.text[doc.prop_offsets[i][0]:doc.prop_offsets[i][1]]) for i in range(len(doc.prop_labels)) if doc.prop_labels[i] == 'MajorClaim'] # handle more than 1 major cliam for main node
    # add the major claims node
    head_node = pydot.Node('\n'.join(maj_claims),style='filled',
                           fillcolor = '#eeccdd')
    arg_graph.add_node(head_node)
    
    nodes = {}
    # add the premise and claims nodes
    for i in range(len(doc.prop_labels)):
        if doc.prop_labels[i] == 'MajorClaim':
            continue
        text = doc.text[doc.prop_offsets[i][0]:doc.prop_offsets[i][1]]
        start = 0
        label = []
        next_i = -1
        for i_c in range(1,len(text)):
            if i_c < next_i:
                continue                
            if i_c % 30 == 0:
                next_i = text.find(" ",i_c) + 1
                if next_i > 0:
                    label.append(text[start:next_i - 1])
                    start = next_i
                else:
                    label.append(text[start:])
                    start = len(text)
        if (i_c > start):
            rest = " " + text[start:]
            if len(rest.split()) == 1:
                label[-1] += rest
            else:
                label.append(text[start:])

        nodes[i] = pydot.Node(i,
                              label = '\n'.join(label),
                              style ='filled',
                              fillcolor = '#ccbbdd' if doc.prop_labels[i] == 'Claim' else '#aabbdd'
                             )
        arg_graph.add_node(nodes[i])
        
    # add edges
    # add the stances (cliams-majorClaims) edges
    for i,val in doc.prop_stances.items():
        tmp_edge = pydot.Edge(nodes[i], head_node,
                              label=val,
                              labelfontcolor='red' if val == "Against" else 'green',
                              color = 'red' if val == "Against" else 'green'
                             )
        arg_graph.add_edge(tmp_edge)
    
    # add the support/attacks edges
    for src,trg in doc.supports:
        tmp_edge = pydot.Edge(nodes[src],nodes[trg])
        arg_graph.add_edge(tmp_edge)
    
    for src, trg in doc.attacks:
        tmp_edge = pydot.Edge(nodes[src],nodes[trg],
                              style = 'dotted',
                              color = 'red'
                             )
        arg_graph.add_edge(tmp_edge)
    
    # display and save
    path = os.path.join(output_path,"essay{:3d}.png".format(doc.ess_id).replace(" ","0"))
    arg_graph.write_png(path)
    print ("saved png to {}".format(path))

# %%
arg_doc_ex = ArgDoc(base_path='/home/yochay/arg_mining_ukp/data/essay095')

# %%
visualizeUKPArgDoc(arg_doc_ex)

# %%
base = '/home/yochay/ukp_argmining_rnn/data/'
output_path = '/home/yochay/ukp_argmining_rnn/graphs/'

essays = [os.path.join(base,"essay{:3d}.ann".format(i).replace(" ","0")) for i in range(1,403)]
for fn in essays:
    argDoc = ArgDoc(fn[:-4])
    visualizeUKPArgDoc(argDoc,output_path)
# Out:
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay1.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay2.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay3.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay4.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay5.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay6.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay7.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay8.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay9.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay10.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay11.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay12.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay13.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay14.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay15.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay16.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay17.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay18.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay19.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay20.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay21.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay22.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay23.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay24.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay25.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay26.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay27.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay28.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay29.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay30.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay31.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay32.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay33.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay34.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay35.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay36.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay37.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay38.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay39.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay40.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay41.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay42.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay43.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay44.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay45.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay46.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay47.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay48.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay49.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay50.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay51.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay52.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay53.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay54.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay55.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay56.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay57.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay58.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay59.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay60.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay61.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay62.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay63.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay64.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay65.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay66.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay67.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay68.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay69.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay70.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay71.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay72.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay73.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay74.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay75.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay76.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay77.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay78.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay79.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay80.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay81.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay82.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay83.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay84.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay85.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay86.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay87.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay88.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay89.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay90.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay91.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay92.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay93.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay94.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay95.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay96.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay97.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay98.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay99.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay100.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay101.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay102.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay103.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay104.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay105.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay106.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay107.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay108.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay109.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay110.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay111.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay112.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay113.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay114.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay115.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay116.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay117.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay118.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay119.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay120.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay121.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay122.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay123.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay124.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay125.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay126.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay127.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay128.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay129.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay130.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay131.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay132.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay133.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay134.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay135.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay136.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay137.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay138.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay139.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay140.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay141.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay142.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay143.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay144.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay145.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay146.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay147.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay148.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay149.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay150.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay151.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay152.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay153.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay154.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay155.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay156.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay157.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay158.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay159.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay160.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay161.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay162.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay163.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay164.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay165.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay166.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay167.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay168.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay169.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay170.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay171.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay172.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay173.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay174.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay175.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay176.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay177.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay178.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay179.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay180.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay181.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay182.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay183.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay184.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay185.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay186.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay187.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay188.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay189.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay190.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay191.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay192.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay193.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay194.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay195.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay196.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay197.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay198.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay199.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay200.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay201.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay202.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay203.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay204.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay205.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay206.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay207.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay208.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay209.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay210.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay211.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay212.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay213.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay214.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay215.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay216.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay217.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay218.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay219.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay220.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay221.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay222.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay223.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay224.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay225.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay226.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay227.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay228.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay229.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay230.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay231.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay232.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay233.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay234.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay235.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay236.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay237.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay238.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay239.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay240.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay241.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay242.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay243.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay244.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay245.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay246.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay247.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay248.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay249.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay250.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay251.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay252.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay253.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay254.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay255.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay256.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay257.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay258.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay259.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay260.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay261.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay262.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay263.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay264.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay265.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay266.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay267.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay268.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay269.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay270.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay271.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay272.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay273.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay274.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay275.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay276.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay277.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay278.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay279.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay280.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay281.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay282.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay283.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay284.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay285.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay286.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay287.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay288.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay289.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay290.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay291.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay292.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay293.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay294.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay295.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay296.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay297.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay298.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay299.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay300.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay301.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay302.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay303.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay304.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay305.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay306.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay307.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay308.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay309.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay310.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay311.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay312.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay313.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay314.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay315.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay316.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay317.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay318.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay319.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay320.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay321.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay322.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay323.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay324.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay325.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay326.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay327.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay328.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay329.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay330.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay331.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay332.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay333.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay334.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay335.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay336.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay337.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay338.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay339.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay340.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay341.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay342.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay343.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay344.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay345.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay346.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay347.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay348.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay349.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay350.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay351.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay352.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay353.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay354.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay355.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay356.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay357.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay358.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay359.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay360.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay361.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay362.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay363.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay364.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay365.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay366.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay367.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay368.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay369.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay370.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay371.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay372.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay373.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay374.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay375.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay376.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay377.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay378.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay379.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay380.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay381.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay382.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay383.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay384.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay385.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay386.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay387.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay388.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay389.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay390.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay391.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay392.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay393.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay394.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay395.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay396.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay397.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay398.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay399.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay400.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay401.png
# saved png to /home/yochay/ukp_argmining_rnn/graphs/essay402.png

# %%
delimited[1]
# Out:
# 'attacks Arg1:T18 Arg2:T16'

# %%
arg_doc_ex.prop_offsets
# Out:
# ((251, 338),
#  (445, 511),
#  (513, 667),
#  (669, 788),
#  (790, 844),
#  (857, 915),
#  (938, 984),
#  (986, 1157),
#  (1166, 1246),
#  (1248, 1355),
#  (1365, 1426),
#  (1443, 1531),
#  (1533, 1584),
#  (1586, 1643),
#  (1645, 1713),
#  (1726, 1783))

# %%
[print("{}\t{}".format(arg_doc_ex.prop_offsets[i],arg_doc_ex.prop_labels[i])) for i in range(len(arg_doc_ex.prop_offsets))];
# Out:
# (251, 338)	MajorClaim
# (445, 511)	Premise
# (513, 667)	Premise
# (669, 788)	Premise
# (790, 844)	Premise
# (857, 915)	Claim
# (938, 984)	Claim
# (986, 1157)	Premise
# (1166, 1246)	Premise
# (1248, 1355)	Premise
# (1365, 1426)	Premise
# (1443, 1531)	MajorClaim
# (1533, 1584)	Premise
# (1586, 1643)	Premise
# (1645, 1713)	Premise
# (1726, 1783)	Claim

# %%
from nltk.parse import CoreNLPParser
from nltk.tokenize import sent_tokenize

# %%
# calculate new proposition offsets w/o spaces
def calc_no_spaces_indices(arg_doc:ArgDoc)->[(int,int)]:
    old_indices = arg_doc.prop_offsets
    text = arg_doc.text
    new_offsets = []
    for (beg,end) in old_indices:
        new_beg = len(text[:beg].replace(" ",""))
        new_end = new_beg + len(text[beg:end].replace(" ",""))
        new_offsets.append(new_beg, new_end)
    return new_offsets

# %%
arg_doc = arg_doc_ex
text = arg_doc_ex.text
pos_tagger = CoreNLPParser(url='http://localhost:9000', tagtype='pos')
output_file = '/home/yochay/arg_mining_proj/data/095ex.preprocessed'

EMPTY_SIGN = "~"

def pre_process_ukp_essay(base_path, pos_tagger):
    arg_doc = ArgDoc(base_path)
    output_file = base_path + ".tsv"
    with open(output_file,'wt',encoding='utf8') as out_f:
        i_no_space = 0
        paragraphs = []
        # list of sentences (list of list of tuples representing tokens and POSs)
        for paragraph in text.split('\n'):
            # token,POS-tag,no_space_index tuple
            tagged_sentences = []
            # skip empty lines (usually seperated from essay title)
            if len(paragraph) == 0:
                continue
            # use nltk sentence tokenizer (PunktSentenceTokenizer)
            sentences = sent_tokenize(paragraph)
            for sent in sentences:
                # use Stanford's CoreNLP for POS tagging sentence by sentence
                pos_tagged_sent = pos_tagger.tag(sent.split())
                tok_pos_noSpaceIndex_sent = []
                for tok, pos in tagged_sent:
                    tok_pos_noSpaceIndex_sent.append(tok,pos,i_no_space)
                    i_no_space += len(tok)
                tagged_sentences.append(tok_pos_noSpaceIndex_sent)
            paragraphs.append(tagged_sentences)

        # add appropriate AC tags by propositions
        no_space_prop_offsets = calc_no_spaces_indices(arg_doc)

        for i_paragraph in range(len(paragraphs)):
            out_f.write("# paragraph {}\n".format(i_paragraph))
            for tagged_sentence in paragraphs(i_paragraph):
                out_f.write("# sent\n")
                for tok,pos,i_no_space in tagged_sentence:
                    # handle AC tagging where propositions apply
                    # inefficient but written in haste for 0ne-time use ... TODO: improve later
                    for i_prop in range(len(no_space_prop_offsets)):
                        # if the current token is in proposition i_prop
                        if (i_no_space => no_space_prop_offsets[i_prop][0] and < no_space_prop_offsets[i_prop][1]):
                            # tag AC information as required (beginning(B) or middle(I) of proposition + AC type)
                            ac_type = arg_doc.prop_lables[i_prop]
                            ac_bio_tag = join("B-" + ac_type) if i_no_space == no_space_prop_offsets[i_prop][0] else join("I-" + ac_type)
                            # tag relation information according to AC type ({AC index:supports\attacks} for premise, For/Against for Claim, empty tab for MajorClaim)
                            rel_tag = EMPTY_SIGN
                            if (ac_type == "Premise"):
                                # either it supports or attacks a claim
                                support_prems, supported = zip(*arg_doc.supports)
                                if i_prop in support_prems:
                                    rel_tag = "supports:{}".format(supported[support_prems.index(i_prop)])
                                else:
                                    attack_prems, attacked = zip(*arg_doc.attacks)
                                    rel_tag = "attacks:{}".format(attacked[attack_prems.index(i_prop)])
                            elif (ac_type == "Claim"):
                                # Claims only have For or Against relation type (they refer to the essay's major claims)
                                rel_tag = "{}:{}".format(arg_doc.stances[i_prop],EMPTY_SIGN)

                            f_out.write("\t".join(tok,pos,ac_bio_tag,i_prop,rel_tag))
                        else:
                            f_out.write("\t".join(tok,pos,EMPTY_SIGN,EMPTY_SIGN,EMPTY_SIGN))
                        f_out.write("\n")
# Out:
# The popularity of news media
# ====================
# Original Sentence:
# The popularity of news media
# The	DT
# popularity	NN
# of	IN
# news	NN
# media	NNS
# ====================
#
# ====================
# Nowadays news media have become more and more popular. Many people consider that the drawbacks of this phenomenon outweigh its merits. However, it is possible that this idea is not completely true. It is widely seen that news media not only brings people entertainment, but also polishes up people' knowledge. Therefore, it seems not unreasonable to suggest that this is a positive development.
# ====================
# Original Sentence:
# Nowadays news media have become more and more popular.
# Nowadays	RB
# news	NN
# media	NNS
# have	VBP
# become	VBN
# more	RBR
# and	CC
# more	RBR
# popular	JJ
# .	.
# ====================
# Original Sentence:
# Many people consider that the drawbacks of this phenomenon outweigh its merits.
# Many	JJ
# people	NNS
# consider	VBP
# that	IN
# the	DT
# drawbacks	NNS
# of	IN
# this	DT
# phenomenon	NN
# outweigh	VBP
# its	PRP$
# merits	NNS
# .	.
# ====================
# Original Sentence:
# However, it is possible that this idea is not completely true.
# However	RB
# ,	,
# it	PRP
# is	VBZ
# possible	JJ
# that	IN
# this	DT
# idea	NN
# is	VBZ
# not	RB
# completely	RB
# true	JJ
# .	.
# ====================
# Original Sentence:
# It is widely seen that news media not only brings people entertainment, but also polishes up people' knowledge.
# It	PRP
# is	VBZ
# widely	RB
# seen	VBN
# that	IN
# news	NN
# media	NNS
# not	RB
# only	RB
# brings	VBZ
# people	NNS
# entertainment	NN
# ,	,
# but	CC
# also	RB
# polishes	VBZ
# up	RP
# people	NNS
# '	POS
# knowledge	NN
# .	.
# ====================
# Original Sentence:
# Therefore, it seems not unreasonable to suggest that this is a positive development.
# Therefore	RB
# ,	,
# it	PRP
# seems	VBZ
# not	RB
# unreasonable	JJ
# to	TO
# suggest	VB
# that	IN
# this	DT
# is	VBZ
# a	DT
# positive	JJ
# development	NN
# .	.
# ====================
# First and foremost, today entertainment is easier for people to enjoy than ever before. The fact is that such news media as televisions, radios, or newspapers are bringing many news on entertainment sector from all over the world to everybody. People can sit in front of their televisions and watch whatever they want, from musical concerts to live football match. This is a convenient way of relaxation after hard work. Obviously, the popularity of news media is beneficial to human beings.
# ====================
# Original Sentence:
# First and foremost, today entertainment is easier for people to enjoy than ever before.
# First	NNP
# and	CC
# foremost	JJ
# ,	,
# today	NN
# entertainment	NN
# is	VBZ
# easier	JJR
# for	IN
# people	NNS
# to	TO
# enjoy	VB
# than	IN
# ever	RB
# before	RB
# .	.
# ====================
# Original Sentence:
# The fact is that such news media as televisions, radios, or newspapers are bringing many news on entertainment sector from all over the world to everybody.
# The	DT
# fact	NN
# is	VBZ
# that	IN
# such	JJ
# news	NN
# media	NNS
# as	IN
# televisions	NNS
# ,	,
# radios	NNS
# ,	,
# or	CC
# newspapers	NNS
# are	VBP
# bringing	VBG
# many	JJ
# news	NN
# on	IN
# entertainment	NN
# sector	NN
# from	IN
# all	DT
# over	IN
# the	DT
# world	NN
# to	TO
# everybody	NN
# .	.
# ====================
# Original Sentence:
# People can sit in front of their televisions and watch whatever they want, from musical concerts to live football match.
# People	NNS
# can	MD
# sit	VB
# in	IN
# front	NN
# of	IN
# their	PRP$
# televisions	NNS
# and	CC
# watch	VB
# whatever	WDT
# they	PRP
# want	VBP
# ,	,
# from	IN
# musical	JJ
# concerts	NNS
# to	TO
# live	VB
# football	NN
# match	NN
# .	.
# ====================
# Original Sentence:
# This is a convenient way of relaxation after hard work.
# This	DT
# is	VBZ
# a	DT
# convenient	JJ
# way	NN
# of	IN
# relaxation	NN
# after	IN
# hard	JJ
# work	NN
# .	.
# ====================
# Original Sentence:
# Obviously, the popularity of news media is beneficial to human beings.
# Obviously	RB
# ,	,
# the	DT
# popularity	NN
# of	IN
# news	NN
# media	NNS
# is	VBZ
# beneficial	JJ
# to	TO
# human	JJ
# beings	NNS
# .	.
# ====================
# In addition to this, news media help people broaden their knowledge. It is clearly seen that mass media provide people with a variety of global news on all fields, including political situation, economic change, global warming, and so forth. Hence, there is a strong likelihood that today people are able to know the world better. This is particularly essential when the globalization process has been permeating into all areas of society. Indeed, the fast growth of news media is helpful for people worldwide.
# ====================
# Original Sentence:
# In addition to this, news media help people broaden their knowledge.
# In	IN
# addition	NN
# to	TO
# this	DT
# ,	,
# news	NN
# media	NNS
# help	VBP
# people	NNS
# broaden	VB
# their	PRP$
# knowledge	NN
# .	.
# ====================
# Original Sentence:
# It is clearly seen that mass media provide people with a variety of global news on all fields, including political situation, economic change, global warming, and so forth.
# It	PRP
# is	VBZ
# clearly	RB
# seen	VBN
# that	IN
# mass	NN
# media	NNS
# provide	VBP
# people	NNS
# with	IN
# a	DT
# variety	NN
# of	IN
# global	JJ
# news	NN
# on	IN
# all	DT
# fields	NNS
# ,	,
# including	VBG
# political	JJ
# situation	NN
# ,	,
# economic	JJ
# change	NN
# ,	,
# global	JJ
# warming	NN
# ,	,
# and	CC
# so	RB
# forth	RB
# .	.
# ====================
# Original Sentence:
# Hence, there is a strong likelihood that today people are able to know the world better.
# Hence	RB
# ,	,
# there	EX
# is	VBZ
# a	DT
# strong	JJ
# likelihood	NN
# that	WDT
# today	NN
# people	NNS
# are	VBP
# able	JJ
# to	TO
# know	VB
# the	DT
# world	NN
# better	RBR
# .	.
# ====================
# Original Sentence:
# This is particularly essential when the globalization process has been permeating into all areas of society.
# This	DT
# is	VBZ
# particularly	RB
# essential	JJ
# when	WRB
# the	DT
# globalization	NN
# process	NN
# has	VBZ
# been	VBN
# permeating	VBG
# into	IN
# all	DT
# areas	NNS
# of	IN
# society	NN
# .	.
# ====================
# Original Sentence:
# Indeed, the fast growth of news media is helpful for people worldwide.
# Indeed	RB
# ,	,
# the	DT
# fast	JJ
# growth	NN
# of	IN
# news	NN
# media	NNS
# is	VBZ
# helpful	JJ
# for	IN
# people	NNS
# worldwide	RB
# .	.
# ====================
# In conclusion, the development of news media has been making great inroads into the lives of all people. It relaxes people with plentiful entertainment news. It enriches people's knowledge with worldwide information. It also positively affects the way people live in many other aspects. Therefore, the progress of news media is an advantageous development.
# ====================
# Original Sentence:
# In conclusion, the development of news media has been making great inroads into the lives of all people.
# In	IN
# conclusion	NN
# ,	,
# the	DT
# development	NN
# of	IN
# news	NN
# media	NNS
# has	VBZ
# been	VBN
# making	VBG
# great	JJ
# inroads	NNS
# into	IN
# the	DT
# lives	NNS
# of	IN
# all	DT
# people	NNS
# .	.
# ====================
# Original Sentence:
# It relaxes people with plentiful entertainment news.
# It	PRP
# relaxes	VBZ
# people	NNS
# with	IN
# plentiful	JJ
# entertainment	NN
# news	NN
# .	.
# ====================
# Original Sentence:
# It enriches people's knowledge with worldwide information.
# It	PRP
# enriches	VBZ
# people	NNS
# 's	POS
# knowledge	NN
# with	IN
# worldwide	JJ
# information	NN
# .	.
# ====================
# Original Sentence:
# It also positively affects the way people live in many other aspects.
# It	PRP
# also	RB
# positively	RB
# affects	VBZ
# the	DT
# way	NN
# people	NNS
# live	VBP
# in	IN
# many	JJ
# other	JJ
# aspects	NNS
# .	.
# ====================
# Original Sentence:
# Therefore, the progress of news media is an advantageous development.
# Therefore	RB
# ,	,
# the	DT
# progress	NN
# of	IN
# news	NN
# media	NNS
# is	VBZ
# an	DT
# advantageous	JJ
# development	NN
# .	.
# ====================
#
# ====================

# %%
arg_doc_ex.prop_stances
# Out:
# {15: 'For', 5: 'For', 6: 'For'}
